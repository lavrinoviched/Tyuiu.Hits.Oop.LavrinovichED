// %% [markdown]
// <h1 style="color:DodgerBlue">Явная реализация интерфейса</h1>

// %% [markdown]
// В C# интерфейсы могут быть реализованы явным и неявным образом. Давайте подробно рассмотрим, что такое явная реализация интерфейсов, реализация интерфейсов в базовых и производных классах, а также наследование интерфейсов, используя примеры классов `Vehicle`, `Car` и `Motorcycle`.
//
// ### Явная реализация интерфейсов
//
// Явная реализация интерфейса используется для того, чтобы скрыть методы интерфейса от стандартного контекста класса. Это означает, что методы интерфейса могут быть вызваны только через ссылку на интерфейс, а не через экземпляр класса.
//
// #### Пример явной реализации
//
// Рассмотрим интерфейс `IVehicle` и его явную реализацию в классе `Car`.
//
// ```csharp
// public interface IVehicle
// {
//     void Start();
//     void Stop();
//     int GetCurrentSpeed();
// }
//
// public class Car : IVehicle
// {
//     public string Make { get; set; }
//     public string Model { get; set; }
//     private int currentSpeed;
//
//     // Явная реализация интерфейса
//     void IVehicle.Start()
//     {
//         currentSpeed = 0;
//         Console.WriteLine($"{Make} {Model} запущен.");
//     }
//
//     void IVehicle.Stop()
//     {
//         currentSpeed = 0;
//         Console.WriteLine($"{Make} {Model} остановлен.");
//     }
//
//     // Неявная реализация метода
//     public int GetCurrentSpeed()
//     {
//         return currentSpeed;
//     }
// }
// ```
//
// В этом примере методы `Start` и `Stop` реализованы явно, и для их вызова необходимо использовать объект типа `IVehicle`:
//
// ```csharp
//
// IVehicle myCar = new Car { Make = "Toyota", Model = "Camry" };
// myCar.Start(); // Корректно, вызывает явную реализацию
// // myCar.Stop(); // Корректно, вызывает явную реализацию
// ```
//
// Если вы попытаетесь вызвать `Start` или `Stop` непосредственно через экземпляр `Car`, это приведёт к ошибке компиляции:
//
// ```csharp
// Car myCar = new Car();
// myCar.Start(); // Ошибка компиляции
// ```
//
// ### Реализация интерфейсов в базовых и производных классах
//
// Интерфейсы могут быть реализованы в базовых классах и наследоваться в производных классах. Давайте рассмотрим эту концепцию на примере, включающем классы `Vehicle`, `Car` и `Motorcycle`.
//
// #### Базовый класс Vehicle
//
// ```csharp
// public abstract class Vehicle : IVehicle
// {
//     public string Make { get; set; }
//     public string Model { get; set; }
//     protected int currentSpeed;
//
//     public abstract void Start();  // Оставляем абстрактным
//     public abstract void Stop();   // Оставляем абстрактным
//
//     public virtual int GetCurrentSpeed()
//     {
//         return currentSpeed;
//     }
// }
// ```
//
// #### Реализация в производных классах
//
// Теперь реализуем `Car` и `Motorcycle`.
//
// ```csharp
// public class Car : Vehicle
// {
//     public override void Start()
//     {
//         currentSpeed = 0;
//         Console.WriteLine($"{Make} {Model} запущен.");
//     }
//
//     public override void Stop()
//     {
//         currentSpeed = 0;
//         Console.WriteLine($"{Make} {Model} остановлен.");
//     }
// }
//
// public class Motorcycle : Vehicle
// {
//     public override void Start()
//     {
//         currentSpeed = 0;
//         Console.WriteLine($"{Make} {Model} мотоцикл запущен.");
//     }
//
//     public override void Stop()
//     {
//         currentSpeed = 0;
//         Console.WriteLine($"{Make} {Model} мотоцикл остановлен.");
//     }
// }
// ```
//
// Теперь оба класса `Car` и `Motorcycle` обязаны реализовать методы `Start` и `Stop`, которые определены в абстрактном классе `Vehicle`.
//
// ### Наследование интерфейсов
//
// Интерфейсы могут наследовать друг от друга. Это позволяет создавать сложные иерархии интерфейсов. Например, мы можем создать интерфейс `IMotorizedVehicle`, который наследует `IVehicle`.
//
// ```csharp
// public interface IMotorizedVehicle : IVehicle
// {
//     void RevEngine();
// }
//
// public class Motorcycle : Vehicle, IMotorizedVehicle
// {
//     public override void Start()
//     {
//         currentSpeed = 0;
//         Console.WriteLine($"{Make} {Model} мотоцикл запущен.");
//     }
//
//     public override void Stop()
//     {
//         currentSpeed = 0;
//         Console.WriteLine($"{Make} {Model} мотоцикл остановлен.");
//     }
//
//     public void RevEngine()
//     {
//         Console.WriteLine("Мотоцикл рычит!");
//     }
// }
// ```
//
// Таким образом, `Motorcycle` теперь может реализовать все методы из обоих интерфейсов `IVehicle` и `IMotorizedVehicle`.
//
// ### Заключение
//
// 1. **Явная реализация** интерфейсов скрывает функциональность классов от общего доступа, что помогает избежать путаницы с методами.
//
// 2. **Реализация интерфейсов в базовых и производных классах** позволяет создавать иерархию классов и обеспечивает обязательность реализации методов в производных классах.
//
// 3. **Наследование интерфейсов** позволяет комбинировать несколько интерфейсов, создавая более сложные структуры, что делает код более гибким и расширяемым.
//
// Эти механизмы являются важными инструментами в инструменте разработчика, позволяя создавать более структурированные и управляемые программы.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Vehicle, Car и Motorcycle ниже в блоке с применением интерфейса и абстактного класса:</h4>
//
// ----

// %%
using System;

public interface IVehicle
{
    void Start();
    void Stop();
    int GetCurrentSpeed();
}

public interface IMotorizedVehicle : IVehicle
{
    void RevEngine();
}

public abstract class Vehicle : IVehicle
{
    public string Make { get; set; }
    public string Model { get; set; }
    protected int currentSpeed;

    void IVehicle.Start()
    {
        currentSpeed = 0;
        Console.WriteLine($"{Make} {Model} запущен через интерфейс.");
    }

    void IVehicle.Stop()
    {
        currentSpeed = 0;
        Console.WriteLine($"{Make} {Model} остановлен через интерфейс.");
    }

    int IVehicle.GetCurrentSpeed()
    {
        return currentSpeed;
    }

    public abstract void Start();
    public abstract void Stop();
    
    public virtual int GetCurrentSpeed()
    {
        return currentSpeed;
    }
}

public class Car : Vehicle
{
    public int NumberOfDoors { get; set; }

    public override void Start()
    {
        currentSpeed = 0;
        Console.WriteLine($"{Make} {Model} автомобиль запущен.");
    }

    public override void Stop()
    {
        currentSpeed = 0;
        Console.WriteLine($"{Make} {Model} автомобиль остановлен.");
    }

    public void Accelerate(int amount)
    {
        currentSpeed += amount;
        Console.WriteLine($"{Make} {Model} разгоняется до {currentSpeed} км/ч.");
    }
}

public class Motorcycle : Vehicle, IMotorizedVehicle
{
    public bool HasSidecar { get; set; }

    public override void Start()
    {
        currentSpeed = 0;
        Console.WriteLine($"{Make} {Model} мотоцикл запущен.");
    }

    public override void Stop()
    {
        currentSpeed = 0;
        Console.WriteLine($"{Make} {Model} мотоцикл остановлен.");
    }

    public void RevEngine()
    {
        Console.WriteLine($"{Make} {Model} рычит: ВРУМ-ВРУМ!");
    }

    public void Wheelie()
    {
        Console.WriteLine($"{Make} {Model} делает вилли!");
    }
}

        Car car = new Car { Make = "Toyota", Model = "Camry", NumberOfDoors = 4 };
        Motorcycle motorcycle = new Motorcycle { Make = "Harley-Davidson", Model = "Sportster", HasSidecar = false };

        car.Start();
        car.Accelerate(60);
        Console.WriteLine($"Текущая скорость автомобиля: {car.GetCurrentSpeed()} км/ч");
        car.Stop();
        
        Console.WriteLine();
        
        motorcycle.Start();
        motorcycle.RevEngine();
        motorcycle.Wheelie();
        Console.WriteLine($"Текущая скорость мотоцикла: {motorcycle.GetCurrentSpeed()} км/ч");
        motorcycle.Stop();
        
        IVehicle vehicle1 = car;
        IVehicle vehicle2 = motorcycle;
        
        vehicle1.Start();  
        Console.WriteLine($"Скорость через интерфейс: {vehicle1.GetCurrentSpeed()} км/ч");
        vehicle1.Stop();
        
        Console.WriteLine();
        
        vehicle2.Start();  
        Console.WriteLine($"Скорость через интерфейс: {vehicle2.GetCurrentSpeed()} км/ч");
        vehicle2.Stop();
        
        IMotorizedVehicle motorizedVehicle = motorcycle;
        motorizedVehicle.Start();    
        motorizedVehicle.RevEngine(); 
        Console.WriteLine($"Скорость: {motorizedVehicle.GetCurrentSpeed()} км/ч");
        motorizedVehicle.Stop();      

        car.Start();    
        motorcycle.Start(); 
        
        IVehicle[] vehicles = new IVehicle[] 
        {
            new Car { Make = "Honda", Model = "Civic", NumberOfDoors = 4 },
            new Motorcycle { Make = "Yamaha", Model = "R1", HasSidecar = false }
        };
        
        foreach (var vehicle in vehicles)
        {
            vehicle.Start();
            Console.WriteLine($"Текущая скорость: {vehicle.GetCurrentSpeed()} км/ч");
            vehicle.Stop();
            Console.WriteLine();
        }
        
        IMotorizedVehicle[] motorizedVehicles = new IMotorizedVehicle[]
        {
            new Motorcycle { Make = "Ducati", Model = "Panigale", HasSidecar = false },
            new Motorcycle { Make = "Kawasaki", Model = "Ninja", HasSidecar = false }
        };
        
        foreach (var mv in motorizedVehicles)
        {
            mv.Start();
            mv.RevEngine();
            mv.Stop();
            Console.WriteLine();
        }
// Out:
// Toyota Camry автомобиль запущен.
// Toyota Camry разгоняется до 60 км/ч.
// Текущая скорость автомобиля: 60 км/ч
// Toyota Camry автомобиль остановлен.
//
// Harley-Davidson Sportster мотоцикл запущен.
// Harley-Davidson Sportster рычит: ВРУМ-ВРУМ!
// Harley-Davidson Sportster делает вилли!
// Текущая скорость мотоцикла: 0 км/ч
// Harley-Davidson Sportster мотоцикл остановлен.
// Toyota Camry запущен через интерфейс.
// Скорость через интерфейс: 0 км/ч
// Toyota Camry остановлен через интерфейс.
//
// Harley-Davidson Sportster мотоцикл запущен.
// Скорость через интерфейс: 0 км/ч
// Harley-Davidson Sportster мотоцикл остановлен.
// Harley-Davidson Sportster мотоцикл запущен.
// Harley-Davidson Sportster рычит: ВРУМ-ВРУМ!
// Скорость: 0 км/ч
// Harley-Davidson Sportster мотоцикл остановлен.
// Toyota Camry автомобиль запущен.
// Harley-Davidson Sportster мотоцикл запущен.
// Honda Civic запущен через интерфейс.
// Текущая скорость: 0 км/ч
// Honda Civic остановлен через интерфейс.
//
// Yamaha R1 мотоцикл запущен.
// Текущая скорость: 0 км/ч
// Yamaha R1 мотоцикл остановлен.
//
// Ducati Panigale мотоцикл запущен.
// Ducati Panigale рычит: ВРУМ-ВРУМ!
// Ducati Panigale мотоцикл остановлен.
//
// Kawasaki Ninja мотоцикл запущен.
// Kawasaki Ninja рычит: ВРУМ-ВРУМ!
// Kawasaki Ninja мотоцикл остановлен.

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (3-4 например Dog, Cat, Bird и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также применить явнаю реализацию интерфейса.

// %%
using System;
using System.Collections.Generic;

public interface IAnimal
{
    string Name { get; set; }
    int Age { get; set; }
    void MakeSound();
    void Eat();
    void Sleep();
}

public interface IPet : IAnimal
{
    string Owner { get; set; }
    void Play();
    bool IsVaccinated { get; set; }
}

public abstract class Animal : IAnimal
{
    private string _name;
    private int _age;

    string IAnimal.Name
    {
        get => _name;
        set => _name = ValidateName(value);
    }

    int IAnimal.Age
    {
        get => _age;
        set => _age = ValidateAge(value);
    }

    void IAnimal.MakeSound() => MakeSoundInternal();
    void IAnimal.Eat() => EatInternal();
    void IAnimal.Sleep() => SleepInternal();

    public string Name
    {
        get => _name;
        set => _name = ValidateName(value);
    }

    public int Age
    {
        get => _age;
        set => _age = ValidateAge(value);
    }

    public abstract void MakeSound();
    public abstract void Eat();
    public abstract void Sleep();

    protected virtual void MakeSoundInternal()
    {
        Console.WriteLine($"{Name} издает звук");
    }

    protected virtual void EatInternal()
    {
        Console.WriteLine($"{Name} ест");
    }

    protected virtual void SleepInternal()
    {
        Console.WriteLine($"{Name} спит");
    }

    private string ValidateName(string name)
    {
        if (string.IsNullOrWhiteSpace(name))
            throw new ArgumentException("Имя не может быть пустым");
        return name.Trim();
    }

    private int ValidateAge(int age)
    {
        if (age < 0)
            throw new ArgumentException("Возраст не может быть отрицательным");
        return age;
    }

    public virtual void DisplayInfo()
    {
        Console.WriteLine($"Животное: {Name}, Возраст: {Age} лет");
    }
}

public class Dog : Animal, IPet
{
    public string Breed { get; set; }
    public bool IsTrained { get; set; }
    public string Owner { get; set; }
    public bool IsVaccinated { get; set; }

    public Dog(string name, int age, string breed, string owner = "Неизвестно")
    {
        Name = name;
        Age = age;
        Breed = breed;
        Owner = owner;
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} громко лает: Гав-гав-гав!");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Name} с удовольствием ест корм для собак");
    }

    public override void Sleep()
    {
        Console.WriteLine($"{Name} крепко спит на своей подстилке и похрапывает");
    }

    public void Play()
    {
        Console.WriteLine($"{Name} весело играет с мячиком!");
    }

    public void Fetch()
    {
        Console.WriteLine($"{Name} приносит палку и виляет хвостом!");
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Порода: {Breed}, Дрессирован: {IsTrained}, Владелец: {Owner}, Привит: {IsVaccinated}");
    }
}

public class Cat : Animal, IPet
{
    public string Color { get; set; }
    public bool IsIndoor { get; set; }
    public string Owner { get; set; }
    public bool IsVaccinated { get; set; }

    public Cat(string name, int age, string color, string owner = "Неизвестно")
    {
        Name = name;
        Age = age;
        Color = color;
        Owner = owner;
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} нежно мяукает: Мяу-мяу-мяу!");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Name} изящно ест рыбу и корм для кошек");
    }

    public override void Sleep()
    {
        Console.WriteLine($"{Name} сладко спит, свернувшись клубочком");
    }

    public void Play()
    {
        Console.WriteLine($"{Name} играет с клубком ниток!");
    }

    public void Purr()
    {
        Console.WriteLine($"{Name} мурлычет: Мрррр-мрррр...");
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Цвет: {Color}, Домашний: {IsIndoor}, Владелец: {Owner}, Привит: {IsVaccinated}");
    }
}

public class Bird : Animal
{
    public double Wingspan { get; set; }
    public bool CanFly { get; set; }
    public string Habitat { get; set; }

    public Bird(string name, int age, double wingspan, string habitat = "Лес")
    {
        Name = name;
        Age = age;
        Wingspan = wingspan;
        Habitat = habitat;
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} весело чирикает: Чик-чирик-чирик!");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Name} клюет зерно и семечки");
    }

    public override void Sleep()
    {
        Console.WriteLine($"{Name} спит на ветке, стоя на одной лапке");
    }

    public void Fly()
    {
        if (CanFly)
            Console.WriteLine($"{Name} летает с размахом крыльев {Wingspan} см");
        else
            Console.WriteLine($"{Name} не умеет летать, но пытается!");
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Размах крыльев: {Wingspan} см, Умеет летать: {CanFly}, Среда обитания: {Habitat}");
    }
}

public class Fish : Animal
{
    public string WaterType { get; set; }
    public double Length { get; set; }
    public string ScaleColor { get; set; }

    public Fish(string name, int age, string waterType, double length, string scaleColor = "Серебристый")
    {
        Name = name;
        Age = age;
        WaterType = waterType;
        Length = length;
        ScaleColor = scaleColor;
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} беззвучно пускает пузыри...");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Name} ест специальный корм для рыб");
    }

    public override void Sleep()
    {
        Console.WriteLine($"{Name} спит, медленно плавая в воде");
    }

    public void Swim()
    {
        Console.WriteLine($"{Name} грациозно плавает в {WaterType} воде");
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Тип воды: {WaterType}, Длина: {Length} см, Цвет чешуи: {ScaleColor}");
    }
}
        var dog = new Dog("Бобик", 3, "Лабрадор", "Иван") { IsTrained = true, IsVaccinated = true };
        var cat = new Cat("Мурка", 2, "Рыжий", "Мария") { IsIndoor = true, IsVaccinated = true };
        var bird = new Bird("Кеша", 1, 15.5, "Парк") { CanFly = true };
        var fish = new Fish("Немо", 1, "морской", 8.5, "Оранжевый");
        
        dog.DisplayInfo();
        dog.MakeSound();
        dog.Eat();
        dog.Play();
        dog.Fetch();
        dog.Sleep();
        Console.WriteLine();

        cat.DisplayInfo();
        cat.MakeSound();
        cat.Eat();
        cat.Play();
        cat.Purr();
        cat.Sleep();
        Console.WriteLine();

        bird.DisplayInfo();
        bird.MakeSound();
        bird.Eat();
        bird.Fly();
        bird.Sleep();
        Console.WriteLine();

        fish.DisplayInfo();
        fish.MakeSound();
        fish.Eat();
        fish.Swim();
        fish.Sleep();
        Console.WriteLine();
        
        IAnimal[] animals = new IAnimal[] { dog, cat, bird, fish };
        
        foreach (var animal in animals)
        {
            animal.MakeSound();
            animal.Eat();
            animal.Sleep();
            Console.WriteLine($"Имя: {animal.Name}, Возраст: {animal.Age} лет");
            Console.WriteLine();
        }
        
        IPet[] pets = new IPet[] { dog, cat };
        
        foreach (var pet in pets)
        {
            pet.MakeSound();
            pet.Eat();
            pet.Play();
            pet.Sleep();
            Console.WriteLine($"Владелец: {pet.Owner}, Привит: {pet.IsVaccinated}");
            Console.WriteLine();
        }
        
        try
        {
            dog.Name = "Новый Бобик";
            dog.Age = 4;
            Console.WriteLine($"Собака теперь: {dog.Name}, возраст: {dog.Age}");
        }
        catch (ArgumentException ex)
        {
            Console.WriteLine($"Ошибка: {ex.Message}");
        }
        
        Animal[] allAnimals = new Animal[] { dog, cat, bird, fish };
        
        foreach (var animal in allAnimals)
        {
            animal.DisplayInfo();
            animal.MakeSound();
            Console.WriteLine();
        }
// Out:
// Животное: Бобик, Возраст: 3 лет
// Порода: Лабрадор, Дрессирован: True, Владелец: Иван, Привит: True
// Бобик громко лает: Гав-гав-гав!
// Бобик с удовольствием ест корм для собак
// Бобик весело играет с мячиком!
// Бобик приносит палку и виляет хвостом!
// Бобик крепко спит на своей подстилке и похрапывает
//
// Животное: Мурка, Возраст: 2 лет
// Цвет: Рыжий, Домашний: True, Владелец: Мария, Привит: True
// Мурка нежно мяукает: Мяу-мяу-мяу!
// Мурка изящно ест рыбу и корм для кошек
// Мурка играет с клубком ниток!
// Мурка мурлычет: Мрррр-мрррр...
// Мурка сладко спит, свернувшись клубочком
//
// Животное: Кеша, Возраст: 1 лет
// Размах крыльев: 15.5 см, Умеет летать: True, Среда обитания: Парк
// Кеша весело чирикает: Чик-чирик-чирик!
// Кеша клюет зерно и семечки
// Кеша летает с размахом крыльев 15.5 см
// Кеша спит на ветке, стоя на одной лапке
//
// Животное: Немо, Возраст: 1 лет
// Тип воды: морской, Длина: 8.5 см, Цвет чешуи: Оранжевый
// Немо беззвучно пускает пузыри...
// Немо ест специальный корм для рыб
// Немо грациозно плавает в морской воде
// Немо спит, медленно плавая в воде
//
// Бобик громко лает: Гав-гав-гав!
// Бобик с удовольствием ест корм для собак
// Бобик крепко спит на своей подстилке и похрапывает
// Имя: Бобик, Возраст: 3 лет
//
// Мурка нежно мяукает: Мяу-мяу-мяу!
// Мурка изящно ест рыбу и корм для кошек
// Мурка сладко спит, свернувшись клубочком
// Имя: Мурка, Возраст: 2 лет
//
// Кеша издает звук
// Кеша ест
// Кеша спит
// Имя: Кеша, Возраст: 1 лет
//
// Немо издает звук
// Немо ест
// Немо спит
// Имя: Немо, Возраст: 1 лет
//
// Бобик громко лает: Гав-гав-гав!
// Бобик с удовольствием ест корм для собак
// Бобик весело играет с мячиком!
// Бобик крепко спит на своей подстилке и похрапывает
// Владелец: Иван, Привит: True
//
// Мурка нежно мяукает: Мяу-мяу-мяу!
// Мурка изящно ест рыбу и корм для кошек
// Мурка играет с клубком ниток!
// Мурка сладко спит, свернувшись клубочком
// Владелец: Мария, Привит: True
//
// Собака теперь: Новый Бобик, возраст: 4
// Животное: Новый Бобик, Возраст: 4 лет
// Порода: Лабрадор, Дрессирован: True, Владелец: Иван, Привит: True
// Новый Бобик громко лает: Гав-гав-гав!
//
// Животное: Мурка, Возраст: 2 лет
// Цвет: Рыжий, Домашний: True, Владелец: Мария, Привит: True
// Мурка нежно мяукает: Мяу-мяу-мяу!
//
// Животное: Кеша, Возраст: 1 лет
// Размах крыльев: 15.5 см, Умеет летать: True, Среда обитания: Парк
// Кеша весело чирикает: Чик-чирик-чирик!
//
// Животное: Немо, Возраст: 1 лет
// Тип воды: морской, Длина: 8.5 см, Цвет чешуи: Оранжевый
// Немо беззвучно пускает пузыри...

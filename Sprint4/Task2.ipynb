// %% [markdown]
// <h1 style="color:DodgerBlue">Управление зависимостями </h1>

// %% [markdown]
// ### Интерфейсы в C#
//
// **Интерфейс** — это контракт, который определяет набор методов и свойств, которые класс должен реализовать. Интерфейсы позволяют создать гибкую и расширяемую архитектуру, поскольку они отделяют определение поведения от его реализации.
//
// Давайте подробно разберем понятия интерфейсов и управления зависимостями в C# на примере классов `Vehicle`, `Car` и `Motorcycle`.
//
// #### Пример интерфейса
//
// Предположим, мы имеем интерфейс `IVehicle`, который определяет поведение транспортных средств. Ниже приведен пример его определения:
//
// ```csharp
// public interface IVehicle
// {
//     void Start();            // Метод для запуска транспортного средства
//     void Stop();             // Метод для остановки транспортного средства
//     int GetNumberOfWheels(); // Метод для получения количества колес
// }
// ```
//
// Интерфейс `IVehicle` требует, чтобы любой класс, реализующий его, обеспечил реализацию этих методов.
//
// ### Реализация интерфейса
//
// Теперь создадим классы `Car` и `Motorcycle`, которые будут реализовывать этот интерфейс:
//
// ```csharp
// public class Car : IVehicle
// {
//     public void Start()
//     {
//         Console.WriteLine("Машина запущена.");
//     }
//
//     public void Stop()
//     {
//         Console.WriteLine("Машина остановлена.");
//     }
//
//     public int GetNumberOfWheels()
//     {
//         return 4; // У машины 4 колеса
//     }
// }
//
// public class Motorcycle : IVehicle
// {
//     public void Start()
//     {
//         Console.WriteLine("Мотоцикл запущен.");
//     }
//
//     public void Stop()
//     {
//         Console.WriteLine("Мотоцикл остановлен.");
//     }
//
//     public int GetNumberOfWheels()
//     {
//         return 2; // У мотоцикла 2 колеса
//     }
// }
// ```
//
// Каждый класс (`Car` и `Motorcycle`) реализует все методы, определенные в интерфейсе `IVehicle`, что позволяет создать единый интерфейс для работы с разными типами транспортных средств.
//
// ### Управление зависимостями (Dependency Injection)
//
// **Управление зависимостями** — это паттерн проектирования, который помогает управлять созданием зависимостей в классе. Этот подход позволяет внедрять (или "вводить") зависимости через конструктор, методы или свойства, вместо того чтобы создавать их внутри класса. Это делает код более чистым и облегчает его тестирование.
//
// #### Пример управления зависимостями
//
// Создадим класс `VehicleService`, который будет зависеть от интерфейса `IVehicle`:
//
// ```csharp
// public class VehicleService
// {
//     private readonly IVehicle _vehicle;
//
//     // Внедрение зависимости через конструктор
//     public VehicleService(IVehicle vehicle)
//     {
//         _vehicle = vehicle;
//     }
//
//     public void UseVehicle()
//     {
//         _vehicle.Start(); // Запускаем транспортное средство
//         Console.WriteLine($"У этого транспортного средства {_vehicle.GetNumberOfWheels()} колеса.");
//         _vehicle.Stop(); // Останавливаем транспортное средство
//     }
// }
// ```
//
// В этом примере класс `VehicleService` принимает в своем конструкторе объект, реализующий интерфейс `IVehicle`. Это позволяет `VehicleService` работать с любым объектом, который реализует `IVehicle`, обеспечивая гибкость и уменьшая связывание между классами.
//
// ### Использование классов
//
// Теперь давайте создадим объекты `Car` и `Motorcycle` и используем наш сервис:
//
// ```csharp
// IVehicle myCar = new Car(); // Создаем объект машины
// VehicleService carService = new VehicleService(myCar); // Передаем машину в сервис
// carService.UseVehicle(); // Используем сервис с машиной
//
// IVehicle myMotorcycle = new Motorcycle(); // Создаем объект мотоцикла
// VehicleService motorcycleService = new VehicleService(myMotorcycle); // Передаем мотоцикл в сервис
// motorcycleService.UseVehicle(); // Используем сервис с мотоциклом
//
// ```
//
// ### Результат выполнения
//
// При запуске данной программы будет следующий вывод:
//
// ```
// Машина запущена.
// У этого транспортного средства 4 колеса.
// Машина остановлена.
// Мотоцикл запущен.
// У этого транспортного средства 2 колеса.
// Мотоцикл остановлен.
// ```
//
// ### Заключение
//
// Использование интерфейсов и управления зависимостями позволяет создать более организованный и тестируемый код. Интерфейсы определяют стандартные поведения, а управление зависимостями снижает связность между компонентами. Это делает систему более гибкой и упрощает процесс её поддержки и расширения в будущем.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Vehicle, Car и Motorcycle ниже в блоке с применением интерфейса и абстактного класса:</h4>
//
// ----

// %%
using System;

public interface IVehicle
{
    void Start();
    void Stop();
    int GetNumberOfWheels();
}

public abstract class Vehicle : IVehicle
{
    public string Make { get; set; }
    public string Model { get; set; }
    
    public abstract void Start();
    public abstract void Stop();
    public abstract int GetNumberOfWheels();
    
    public virtual void DisplayInfo()
    {
        Console.WriteLine($"Транспортное средство: {Make} {Model}");
    }
}

public class Car : Vehicle
{
    public int NumberOfDoors { get; set; }
    
    public override void Start()
    {
        Console.WriteLine($"{Make} {Model} автомобиль запущен.");
    }
    
    public override void Stop()
    {
        Console.WriteLine($"{Make} {Model} автомобиль остановлен.");
    }
    
    public override int GetNumberOfWheels()
    {
        return 4;
    }
    
    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Количество дверей: {NumberOfDoors}");
    }
}

public class Motorcycle : Vehicle
{
    public bool HasSidecar { get; set; }
    
    public override void Start()
    {
        Console.WriteLine($"{Make} {Model} мотоцикл запущен.");
    }
    
    public override void Stop()
    {
        Console.WriteLine($"{Make} {Model} мотоцикл остановлен.");
    }
    
    public override int GetNumberOfWheels()
    {
        return HasSidecar ? 3 : 2;
    }
    
    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Есть коляска: {(HasSidecar ? "Да" : "Нет")}");
    }
}

public class VehicleService
{
    private readonly IVehicle _vehicle;

    public VehicleService(IVehicle vehicle)
    {
        _vehicle = vehicle;
    }

    public void UseVehicle()
    {
        _vehicle.Start();
        Console.WriteLine($"У этого транспортного средства {_vehicle.GetNumberOfWheels()} колеса.");
        _vehicle.Stop();
    }
    
    public void TestVehicle()
    {
        Console.WriteLine("Тестирование транспортного средства");
        _vehicle.Start();
        Console.WriteLine($"Количество колес: {_vehicle.GetNumberOfWheels()}");
        _vehicle.Stop();
    }
}

        IVehicle myCar = new Car { Make = "Toyota", Model = "Camry" };
        VehicleService carService = new VehicleService(myCar);
        carService.UseVehicle();
        
        Console.WriteLine();
        
        IVehicle myMotorcycle = new Motorcycle { Make = "Harley-Davidson", Model = "Sportster", HasSidecar = false };
        VehicleService motorcycleService = new VehicleService(myMotorcycle);
        motorcycleService.UseVehicle();
        
        Console.WriteLine();
        
        IVehicle motorcycleWithSidecar = new Motorcycle { Make = "Ural", Model = "Gear-Up", HasSidecar = true };
        VehicleService sidecarService = new VehicleService(motorcycleWithSidecar);
        sidecarService.UseVehicle();
        
        Vehicle[] vehicles = new Vehicle[]
        {
            new Car { Make = "Honda", Model = "Civic", NumberOfDoors = 4 },
            new Motorcycle { Make = "Yamaha", Model = "R1", HasSidecar = false },
            new Motorcycle { Make = "BMW", Model = "R1200", HasSidecar = true }
        };
        
        foreach (var vehicle in vehicles)
        {
            vehicle.DisplayInfo();
            VehicleService service = new VehicleService(vehicle);
            service.TestVehicle();
            Console.WriteLine();
        }
        
        IVehicle[] allVehicles = new IVehicle[]
        {
            new Car { Make = "Ford", Model = "Focus", NumberOfDoors = 5 },
            new Motorcycle { Make = "Kawasaki", Model = "Ninja", HasSidecar = false }
        };
        
        foreach (var vehicle in allVehicles)
        {
            VehicleService universalService = new VehicleService(vehicle);
            universalService.UseVehicle();
            Console.WriteLine();
        }
// Out:
// Toyota Camry автомобиль запущен.
// У этого транспортного средства 4 колеса.
// Toyota Camry автомобиль остановлен.
//
// Harley-Davidson Sportster мотоцикл запущен.
// У этого транспортного средства 2 колеса.
// Harley-Davidson Sportster мотоцикл остановлен.
//
// Ural Gear-Up мотоцикл запущен.
// У этого транспортного средства 3 колеса.
// Ural Gear-Up мотоцикл остановлен.
// Транспортное средство: Honda Civic
// Количество дверей: 4
// Тестирование транспортного средства
// Honda Civic автомобиль запущен.
// Количество колес: 4
// Honda Civic автомобиль остановлен.
//
// Транспортное средство: Yamaha R1
// Есть коляска: Нет
// Тестирование транспортного средства
// Yamaha R1 мотоцикл запущен.
// Количество колес: 2
// Yamaha R1 мотоцикл остановлен.
//
// Транспортное средство: BMW R1200
// Есть коляска: Да
// Тестирование транспортного средства
// BMW R1200 мотоцикл запущен.
// Количество колес: 3
// BMW R1200 мотоцикл остановлен.
//
// Ford Focus автомобиль запущен.
// У этого транспортного средства 4 колеса.
// Ford Focus автомобиль остановлен.
//
// Kawasaki Ninja мотоцикл запущен.
// У этого транспортного средства 2 колеса.
// Kawasaki Ninja мотоцикл остановлен.

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (3-4 например Dog, Cat, Bird и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также реализовать управление зависимостями.

// %%
using System;
using System.Collections.Generic;

public interface IAnimal
{
    string Name { get; set; }
    int Age { get; set; }
    void MakeSound();
    void Eat();
    void Sleep();
}

public abstract class Animal : IAnimal
{
    private string _name;
    private int _age;

    public string Name
    {
        get => _name;
        set => _name = string.IsNullOrWhiteSpace(value) ? throw new ArgumentException("Имя не может быть пустым") : value.Trim();
    }

    public int Age
    {
        get => _age;
        set => _age = value < 0 ? throw new ArgumentException("Возраст не может быть отрицательным") : value;
    }

    public abstract void MakeSound();
    public abstract void Eat();
    public abstract void Sleep();

    public virtual void DisplayInfo()
    {
        Console.WriteLine($"Животное: {Name}, Возраст: {Age} лет");
    }
}

public class Dog : Animal
{
    public string Breed { get; set; }
    public bool IsTrained { get; set; }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} громко лает: Гав-гав!");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Name} ест корм для собак");
    }

    public override void Sleep()
    {
        Console.WriteLine($"{Name} спит на своей подстилке");
    }

    public void Fetch()
    {
        Console.WriteLine($"{Name} приносит палку!");
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Порода: {Breed}, Дрессирован: {(IsTrained ? "Да" : "Нет")}");
    }
}

public class Cat : Animal
{
    public string Color { get; set; }
    public bool IsIndoor { get; set; }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} мяукает: Мяу-мяу!");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Name} ест рыбу и корм для кошек");
    }

    public override void Sleep()
    {
        Console.WriteLine($"{Name} спит на диване");
    }

    public void Purr()
    {
        Console.WriteLine($"{Name} мурлычет: Мрррр...");
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Цвет: {Color}, Домашний: {(IsIndoor ? "Да" : "Нет")}");
    }
}

public class Bird : Animal
{
    public double Wingspan { get; set; }
    public bool CanFly { get; set; }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} чирикает: Чик-чирик!");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Name} клюет зерно и семечки");
    }

    public override void Sleep()
    {
        Console.WriteLine($"{Name} спит на ветке");
    }

    public void Fly()
    {
        if (CanFly)
            Console.WriteLine($"{Name} летает с размахом крыльев {Wingspan} см");
        else
            Console.WriteLine($"{Name} не умеет летать");
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Размах крыльев: {Wingspan} см, Умеет летать: {(CanFly ? "Да" : "Нет")}");
    }
}

public class Fish : Animal
{
    public string WaterType { get; set; }
    public double Length { get; set; }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} пускает пузыри: Буль-буль!");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Name} ест корм для рыб");
    }

    public override void Sleep()
    {
        Console.WriteLine($"{Name} спит в воде");
    }

    public void Swim()
    {
        Console.WriteLine($"{Name} плавает в {WaterType} воде");
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Тип воды: {WaterType}, Длина: {Length} см");
    }
}

public class AnimalService
{
    private readonly IAnimal _animal;

    public AnimalService(IAnimal animal)
    {
        _animal = animal;
    }

    public void CareForAnimal()
    {
        Console.WriteLine($" Уход за {_animal.Name}");
        _animal.Eat();
        _animal.Sleep();
    }

    public void TestAnimal()
    {
        Console.WriteLine($" Тестирование {_animal.Name} ");
        _animal.MakeSound();
        _animal.Eat();
        _animal.Sleep();
    }
}

public class Zoo
{
    private readonly List<IAnimal> _animals;
    private readonly AnimalService _animalService;

    public Zoo(AnimalService animalService)
    {
        _animals = new List<IAnimal>();
        _animalService = animalService;
    }

    public void AddAnimal(IAnimal animal)
    {
        _animals.Add(animal);
        Console.WriteLine($"{animal.Name} добавлен в зоопарк");
    }

    public void CareForAllAnimals()
    {
        Console.WriteLine("\n Уход за всеми животными в зоопарке");
        foreach (var animal in _animals)
        {
            var service = new AnimalService(animal);
            service.CareForAnimal();
        }
    }

    public void ShowAllAnimals()
    {
        Console.WriteLine("\n Все животные в зоопарке");
        foreach (var animal in _animals)
        {
            if (animal is Animal concreteAnimal)
            {
                concreteAnimal.DisplayInfo();
            }
            Console.WriteLine();
        }
    }
}

        var dog = new Dog { Name = "Бобик", Age = 3, Breed = "Лабрадор", IsTrained = true };
        var cat = new Cat { Name = "Мурка", Age = 2, Color = "Рыжий", IsIndoor = true };
        var bird = new Bird { Name = "Кеша", Age = 1, Wingspan = 15.5, CanFly = true };
        var fish = new Fish { Name = "Немо", Age = 1, WaterType = "морской", Length = 8.5 };

        var animalService = new AnimalService(dog);
        var zoo = new Zoo(animalService);

        zoo.AddAnimal(dog);
        zoo.AddAnimal(cat);
        zoo.AddAnimal(bird);
        zoo.AddAnimal(fish);

        zoo.ShowAllAnimals();
        zoo.CareForAllAnimals();
        
        AnimalService dogService = new AnimalService(dog);
        dogService.TestAnimal();

        AnimalService catService = new AnimalService(cat);
        catService.CareForAnimal();

        AnimalService birdService = new AnimalService(bird);
        birdService.TestAnimal();
        
        IAnimal[] animals = new IAnimal[] { dog, cat, bird, fish };
        
        foreach (var animal in animals)
        {
            AnimalService service = new AnimalService(animal);
            service.CareForAnimal();
        }

        Console.WriteLine("\n Специфическое поведение животных ");
        
        dog.Fetch();
        cat.Purr();
        bird.Fly();
        fish.Swim();
        
        try
        {
            dog.Name = "Рекс";
            dog.Age = 4;
            Console.WriteLine($"Собака теперь: {dog.Name}, возраст: {dog.Age}");
        }
        catch (ArgumentException ex)
        {
            Console.WriteLine($"Ошибка: {ex.Message}");
        }
// Out:
// Бобик добавлен в зоопарк
// Мурка добавлен в зоопарк
// Кеша добавлен в зоопарк
// Немо добавлен в зоопарк
//
//  Все животные в зоопарке
// Животное: Бобик, Возраст: 3 лет
// Порода: Лабрадор, Дрессирован: Да
//
// Животное: Мурка, Возраст: 2 лет
// Цвет: Рыжий, Домашний: Да
//
// Животное: Кеша, Возраст: 1 лет
// Размах крыльев: 15.5 см, Умеет летать: Да
//
// Животное: Немо, Возраст: 1 лет
// Тип воды: морской, Длина: 8.5 см
//
//
//  Уход за всеми животными в зоопарке
//  Уход за Бобик
// Бобик ест корм для собак
// Бобик спит на своей подстилке
//  Уход за Мурка
// Мурка ест рыбу и корм для кошек
// Мурка спит на диване
//  Уход за Кеша
// Кеша клюет зерно и семечки
// Кеша спит на ветке
//  Уход за Немо
// Немо ест корм для рыб
// Немо спит в воде
//  Тестирование Бобик
// Бобик громко лает: Гав-гав!
// Бобик ест корм для собак
// Бобик спит на своей подстилке
//  Уход за Мурка
// Мурка ест рыбу и корм для кошек
// Мурка спит на диване
//  Тестирование Кеша
// Кеша чирикает: Чик-чирик!
// Кеша клюет зерно и семечки
// Кеша спит на ветке
//  Уход за Бобик
// Бобик ест корм для собак
// Бобик спит на своей подстилке
//  Уход за Мурка
// Мурка ест рыбу и корм для кошек
// Мурка спит на диване
//  Уход за Кеша
// Кеша клюет зерно и семечки
// Кеша спит на ветке
//  Уход за Немо
// Немо ест корм для рыб
// Немо спит в воде
//
//  Специфическое поведение животных
// Бобик приносит палку!
// Мурка мурлычет: Мрррр...
// Кеша летает с размахом крыльев 15.5 см
// Немо плавает в морской воде
// Собака теперь: Рекс, возраст: 4
